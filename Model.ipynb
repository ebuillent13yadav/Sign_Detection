# %% [markdown]
# <a href="https://colab.research.google.com/github/ebuillent13yadav/Sign_Detection/blob/main/Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# %%
img_size = 128
batch_size = 8

# %%
# augmentation
train_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 15,
    zoom_range = 0.1,
    brightness_range = [0.8, 1.2]
)

# %%
val_datagen = ImageDataGenerator(
    rescale = 1./255
)

# %%
train_generator = train_datagen.flow_from_directory(
    "/content/drive/MyDrive/dataset_sign_detection/train",
    target_size = (img_size, img_size),
    batch_size = batch_size,
    class_mode = 'categorical'
)
# Out:
# Found 50 images belonging to 10 classes.

# %%
val_generator = val_datagen.flow_from_directory(
    "/content/drive/MyDrive/dataset_sign_detection/val",
    target_size = (img_size, img_size),
    batch_size = batch_size,
    class_mode = 'categorical'
)
# Out:
# Found 10 images belonging to 10 classes.

# %%
model = Sequential([

    Conv2D(16, (3,3), activation='relu', input_shape = (128, 128, 3)),
    MaxPooling2D(2,2),

    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),

    Dense(64, activation='relu'),
    Dropout(0.5),

    Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer = 'adam',
    loss = 'categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_generator,
    validation_data = val_generator,
    epochs=25
)
# Out:
# Epoch 1/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 19s 2s/step - accuracy: 0.0311 - loss: 2.4890 - val_accuracy: 0.1000 - val_loss: 2.3013
# Epoch 2/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 205ms/step - accuracy: 0.1381 - loss: 2.3071 - val_accuracy: 0.1000 - val_loss: 2.3003
# Epoch 3/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 200ms/step - accuracy: 0.0611 - loss: 2.3005 - val_accuracy: 0.1000 - val_loss: 2.2988
# Epoch 4/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - accuracy: 0.0984 - loss: 2.2971 - val_accuracy: 0.1000 - val_loss: 2.2918
# Epoch 5/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 196ms/step - accuracy: 0.1142 - loss: 2.2937 - val_accuracy: 0.3000 - val_loss: 2.2833
# Epoch 6/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 224ms/step - accuracy: 0.0908 - loss: 2.2777 - val_accuracy: 0.2000 - val_loss: 2.2638
# Epoch 7/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 204ms/step - accuracy: 0.2231 - loss: 2.2378 - val_accuracy: 0.1000 - val_loss: 2.2493
# Epoch 8/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 266ms/step - accuracy: 0.2850 - loss: 2.2379 - val_accuracy: 0.6000 - val_loss: 2.2002
# Epoch 9/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 345ms/step - accuracy: 0.3890 - loss: 2.1578 - val_accuracy: 0.5000 - val_loss: 2.0917
# Epoch 10/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 277ms/step - accuracy: 0.3803 - loss: 2.0358 - val_accuracy: 0.5000 - val_loss: 1.9130
# Epoch 11/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 203ms/step - accuracy: 0.4435 - loss: 1.8281 - val_accuracy: 0.6000 - val_loss: 1.7268
# Epoch 12/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 201ms/step - accuracy: 0.4392 - loss: 1.8876 - val_accuracy: 0.6000 - val_loss: 1.5282
# Epoch 13/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 200ms/step - accuracy: 0.5769 - loss: 1.3915 - val_accuracy: 0.8000 - val_loss: 1.3550
# Epoch 14/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 234ms/step - accuracy: 0.6524 - loss: 1.3783 - val_accuracy: 0.9000 - val_loss: 0.8594
# Epoch 15/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.8032 - loss: 0.8146 - val_accuracy: 0.8000 - val_loss: 0.6292
# Epoch 16/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 198ms/step - accuracy: 0.7686 - loss: 0.7197 - val_accuracy: 0.8000 - val_loss: 0.6332
# Epoch 17/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 333ms/step - accuracy: 0.6288 - loss: 0.9448 - val_accuracy: 0.8000 - val_loss: 0.6092
# Epoch 18/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 342ms/step - accuracy: 0.7442 - loss: 0.6686 - val_accuracy: 0.8000 - val_loss: 0.5171
# Epoch 19/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 215ms/step - accuracy: 0.9196 - loss: 0.4045 - val_accuracy: 0.9000 - val_loss: 0.6070
# Epoch 20/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 209ms/step - accuracy: 0.8555 - loss: 0.3683 - val_accuracy: 0.8000 - val_loss: 0.5495
# Epoch 21/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 200ms/step - accuracy: 0.8852 - loss: 0.3308 - val_accuracy: 0.8000 - val_loss: 0.6201
# Epoch 22/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - accuracy: 0.9128 - loss: 0.3190 - val_accuracy: 0.8000 - val_loss: 0.6242
# Epoch 23/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 238ms/step - accuracy: 0.8000 - loss: 0.4730 - val_accuracy: 0.8000 - val_loss: 0.6697
# Epoch 24/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 205ms/step - accuracy: 0.8526 - loss: 0.4081 - val_accuracy: 0.8000 - val_loss: 0.5843
# Epoch 25/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 217ms/step - accuracy: 0.9766 - loss: 0.1671 - val_accuracy: 0.8000 - val_loss: 0.5882

# %%
model.save("gesture_model.keras")

# %%
# from tensorflow.keras.models.models import load_model
# model = load_model("gesture_model.keras")
